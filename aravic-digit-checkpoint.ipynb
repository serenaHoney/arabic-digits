# %%
import numpy as np
import librosa 
import matplotlib.pyplot as plt
import IPython.display as ipd
import scipy


 
arabic_digit = r"C:\Users\elizh\OneDrive\Documents\Academics\University Maths\Year 2\Arabic_digit_project\Train_Arabic_Digit.txt"

data = np.loadtxt(arabic_digit)
print(data)
mfcc = data[2:39]
wav = librosa.feature.inverse.mfcc_to_audio(mfcc)
print('wav: ', wav)
def show_data(data):
    plt.figure()
    plt.title("data")
    plt.plot(data)
    plt.show()

show_data(wav)
ipd.Audio(wav, rate=11025)
# Out:
# [[-0.81101  -7.2382    1.5429   ...  0.044692  0.20817   0.5114  ]
#  [-0.37028  -7.1336    1.8856   ...  0.086109  0.6269    0.78115 ]
#  [ 0.59659  -8.3059    1.6943   ...  0.57163   0.45316   0.64465 ]
#  ...
#  [ 4.6918   -5.0641   -2.7542   ... -0.72777   0.43086  -1.0494  ]
#  [ 3.3359   -4.3017   -2.7763   ... -0.22065   0.64316  -0.78685 ]
#  [ 2.2493   -4.1621   -1.4541   ... -0.37872   0.45075  -0.56474 ]]
# wav:  [ 0.23240001  0.04804602  0.0348935  ...  0.06319176 -0.08531033
#  -0.15051742]
# <img src="data:image/png;base64,..." width="640">
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
